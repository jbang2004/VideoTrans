# %%
from funasr import AutoModel
from funasr.utils.postprocess_utils import rich_transcription_postprocess

# %%
model_dir = "iic/SenseVoiceSmall"
model = AutoModel(
    model=model_dir,
    trust_remote_code=True,
    remote_code="./model.py",    
    vad_model="fsmn-vad",
    spk_model="cam++",
    vad_kwargs={"max_single_segment_time": 30000},
    device="cpu",
)
# Out:
# funasr version: 1.2.3.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# New version is available: 1.2.6.
# Please use the command "pip install -U funasr" to upgrade.
# 2025-04-26 09:30:37,844 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# Loading remote code failed: ./model.py, No module named 'model'
# 2025-04-26 09:30:40,302 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# 2025-04-26 09:30:41,121 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# 2025-04-26 09:30:56,790 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# Detect model requirements, begin to install it: /home/jbang/.cache/modelscope/hub/iic/speech_campplus_sv_zh-cn_16k-common/requirements.txt
# install model requirements successfully

# %%
res = model.generate(
    input=f"vocals_0.wav",
    cache={},
    language="auto",  # "zh", "en", "yue", "ja", "ko", "nospeech"
    use_itn=False,
    batch_size_s=60,
    merge_vad=True,  #
    merge_length_s=15,
)
text = rich_transcription_postprocess(res[0]["text"])
print(text)
# Out:
# rtf_avg: 0.015: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
#
#
# rtf_avg: 0.209: 100%|██████████| 1/1 [00:00<00:00, 15.49it/s]
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00, 32.49it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.033: 100%|██████████| 1/1 [00:00<00:00,  6.74it/s]
#
#
#
#
#
#
# rtf_avg: 0.010: 100%|██████████| 8/8 [00:00<00:00, 99.61it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.031: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 12/12 [00:00<00:00, 140.14it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 14/14 [00:00<00:00, 135.36it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 15/15 [00:00<00:00, 140.15it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 16/16 [00:00<00:00, 144.44it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.028: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 16/16 [00:00<00:00, 153.90it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.028: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 18/18 [00:00<00:00, 148.63it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.026: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 24/24 [00:00<00:00, 151.52it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.027: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 24/24 [00:00<00:00, 152.63it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.026: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 24/24 [00:00<00:00, 165.08it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.027: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 26/26 [00:00<00:00, 153.06it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.027: 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 29/29 [00:00<00:00, 152.59it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.027: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 33/33 [00:00<00:00, 150.34it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.027: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 44/44 [00:00<00:00, 148.32it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.028: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 44/44 [00:00<00:00, 151.68it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 60/60 [00:00<00:00, 147.16it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 60/60 [00:00<00:00, 154.41it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 60/60 [00:00<00:00, 155.05it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.007: 100%|██████████| 60/60 [00:00<00:00, 148.13it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 60/60 [00:00<00:00, 154.21it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
#
#
#
# rtf_avg: 0.006: 100%|██████████| 60/60 [00:00<00:00, 155.95it/s]
#
#
#
#
#
#
#
#
# rtf_avg: -1.310: 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
#
#
# rtf_avg: 0.046, time_speech:  358.284, time_escape: 16.434: 100%|██████████| 1/1 [00:16<00:00, 16.66s/it]
# < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >还有你的绯闻，还有你的绯闻，就是说你和这个王总就这样一些话题的背后，你想过会跟你发生关系吗？我看都不看。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >我觉得没所谓，现在就是我们的王猛来，我告诉大家呢，这是大家社会公认的小鲜肉。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >从一个网红过期网红，然后到了这个企业有多长时间了？我看两两年多了啊，快两年半了，这两年多，你觉得你经历了什么样的变化？我觉得这个适应和变化的过程对我来说，其实< | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >.是一个挺美妙，但是也挺呃需要去努力适应的一个过程。但是也有很多人会说呦，看< | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >董明珠给了他一个多好的机会。好多人都会觉得哎呀，这个机会我也很羡慕。但是也有人会说，你看这个人是蹭这个格力流量的，还有人会说他就是打酱用有有小鲜肉是吧？然后这个说我这个呃过来凑流量，镀个金两年就走了，对吧？他不是说到格力来是唱流量，到格力来说，哎，捞一把他不是的。我觉得我我其实这两年时间里边不太关注大家怎么评价我，我就我们在< | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >在德的每一个人终究有一天会离开这家企业的。但是当你有一天终究离开这家企业的时候，你回头看< | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >你到底为这家企业留下了什么？这是我在乎的事儿。有些事如果两年三年看不清，但是五年以后很清楚，这种东西就一定要做，这叫战略。如果你把一个决色放在二十年到三十年的程度再去思考，你可能会做出很多让别人不理解的决定。但是这叫价值观。如果你把一个决定放在人生的程度再去思考，你就会觉得你真正在乎的只有你临死之前对自己一生的评价，这叫人生观。我觉得来加入格力电器这个动作，可能至少是我放在二三十年。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >要思考的事情。因为在过去这几年当中，我们其实看到呃，格力其实容纳了，包括你在内的还有好几个网红啊，然后有的网红离开了。然后但是你还留在这儿，那你想到我篡位啊，根本不是在一个起业老线上啊，他不能把它雷同，从他们那些人是一个级别的。嗯，一个是刚从学校出来，完全一无所知的情况来下嗯，他是经历过市场的断炼，他已摸打了那么多年是对< | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >这完全是说他对人生的认知是不在一个层面的。一个前辈给我分享的一个故事，他说，自如。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >你们在大学里学的所有知识，其实在社会实践当中是严重破解的。因为之所以能够进入教科书，都是过去的经验，但是我们现在今天知识发证才是最有价值的，所以就证明你是一张白纸，其实你什么都不会。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >然后你什么都不会，你做事情的时候一定会犯错。然后你的公司一定要为你犯的错误买单，然后还有人教你怎么做事。呃，这个是这还不算完嗯，还有人给你发钱吗？ < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >哎，你不就这这件事情哪有这么好的事，你知道我们所有人都很羡慕。你跟着董姐在一起，她吃过的亏，上过的当以及她建立过的东西，他都把经验告诉你。是的，所以当时我就总结一句话，我觉得我说刚毕业的年轻人一定要学会心态归零。然后第二个就是我当时就曾经幻想过，有一天如果我的职业生涯当中能有那么一段经历，可以跟在一个顶级的企业家身边从事工作展开工作。我哪怕每天什么事都不干，我们就看他怎么看。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >开会。我听他们该讲什么，做什么，我都觉得是一件很幸福的事儿。我真的讲过，那是他知道一个人成功，靠你在外面，你必须要有一个整体的力量，你才能够有实现成功。所以人家讲团队精神，我跟他认识连续很久，但是我们后来就没脸是一次偶然的机会。 < | en | > < | EMO _ UNKNOWN | > < | S pee ch | > < | wo itn | > < | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >他真的是一次玩机会，是很偶人的机会。因为没有京东的直播搞直播吗？对，京东就这样又见绍了见上。我觉得哎这个小孩子变化的对变化很大，仅仅是说在能干和不能干，你是我总觉记，能让他能干和不干。就是我只是给他开了一个门，而他有些人进了这个梦里，然后然完全看到自己，所以我还是因为我比较喜欢他特有，就他们进也经在他们这一代面龄。 < | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >已经很傻。嗯，这是我默默看的电影。其实今天第一次讲座，他怎么知道< | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >所以我必须应该的努力的。哎，我很好奇哈，作为公司的高，管你一个月的收入情况怎么样。其实我说实话我没有看过格离狗的工资表。 < | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >我真没看过，我不知道那就是说吃饭不花钱，然后住宿舍还有。对，就没看过公司了。因为我来格力电器的时候，我就我就说我说董总能不能给我一间离您比较近的办公室，我说随时临您汇报，然后其他的我觉得不重要。我最开始刚来公司第一个月在团队开会的时候，我就跟团队讲，我说兄弟们。 < | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >格力电器今天的辉煌跟我们没关系。但是< | zh | > < | HAPPY | > < | S pee ch | > < | wo itn | >如果今天我们加入格力电器格离的下一个三十年跟我没有关系。当然我也不是说我要来在格力电器三十年啊，这取决于董总，还觉得我还能不能给公司做点贡献啊，如果可以的话，我愿意一直做下去。但是这里面其实我我内心当中非常感激的一个点，就是我觉得董总在启用我的时候，其实确实承担了巨大的压力，也体现出来的极强的魄力。我觉得在使我信我知我用我的这种状态下，一个三十多岁的< | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >呃，年轻人可能这是他最难得去遇到的一种境遇和治遇的一种情怀。我跟董总去沟通交流的时候，有一句话是真正击中我的，就是他说自如，这可能是你。 < | zh | > < | NEUTRAL | > < | S pee ch | > < | wo itn | >改变你下半生的一次决定。其实我脑子里边一直在萦绕着这句话，到最后促使我真正的决定加入格力电器的一个主要的原因是这个。
